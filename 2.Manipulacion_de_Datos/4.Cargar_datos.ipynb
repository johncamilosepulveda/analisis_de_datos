# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from pymongo import MongoClient
import sqlalchemy as db

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn = engine.connect()

# %%
customers_df = pd.read_sql('customers', con=conn)

# %%
connection_string = 'mongodb+srv://johncamilosepulveda:rkLyONLXmVj339Sw@cluster0.dhex9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
Client = MongoClient(connection_string)

# %%
db_name = Client['retail_bd']
collection_name = db_name['customers']

# %%
#Transformación de datos hacia mongo
df_to_dict = customers_df.to_dict("records")

#Carga de datos a mongo
collection_name.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('66ecd64969bc05e8655a0b9b'), ObjectId('66ecd64969bc05e8655a0b9c'), ObjectId('66ecd64969bc05e8655a0b9d'), ObjectId('66ecd64969bc05e8655a0b9e'), ObjectId('66ecd64969bc05e8655a0b9f'), ObjectId('66ecd64969bc05e8655a0ba0'), ObjectId('66ecd64969bc05e8655a0ba1'), ObjectId('66ecd64969bc05e8655a0ba2'), ObjectId('66ecd64969bc05e8655a0ba3'), ObjectId('66ecd64969bc05e8655a0ba4'), ObjectId('66ecd64969bc05e8655a0ba5'), ObjectId('66ecd64969bc05e8655a0ba6'), ObjectId('66ecd64969bc05e8655a0ba7'), ObjectId('66ecd64969bc05e8655a0ba8'), ObjectId('66ecd64969bc05e8655a0ba9'), ObjectId('66ecd64969bc05e8655a0baa'), ObjectId('66ecd64969bc05e8655a0bab'), ObjectId('66ecd64969bc05e8655a0bac'), ObjectId('66ecd64969bc05e8655a0bad'), ObjectId('66ecd64969bc05e8655a0bae'), ObjectId('66ecd64969bc05e8655a0baf'), ObjectId('66ecd64969bc05e8655a0bb0'), ObjectId('66ecd64969bc05e8655a0bb1'), ObjectId('66ecd64969bc05e8655a0bb2'), ObjectId('66ecd64969bc05e8655a0bb3'), ObjectId('66ecd64969bc05e8655a
# ...

# %%
customers =  collection_name.find({'customer_state':'NY'})
customers

# %%
customers_df = pd.DataFrame(customers)

# %%
customers_df.head()
# Out:
#                         _id  customer_id customer_fname customer_lname  \
# 0  66ecd64969bc05e8655a0bc3           41       Victoria          Mason
# 1  66ecd64969bc05e8655a0bc8           46       Jennifer          Smith
# 2  66ecd64969bc05e8655a0bd6           60           Mary      Gutierrez
# 3  66ecd64969bc05e8655a0bd8           62           Mary          Oneal
# 4  66ecd64969bc05e8655a0beb           81           Mary          Smith
#
#   customer_email customer_password           customer_street customer_city  \
# 0      XXXXXXXXX         XXXXXXXXX  7869 Crystal View Villas      Brooklyn
# 1      XXXXXXXXX         XXXXXXXXX      5463 Rocky Autoroute      Freeport
# 2      XXXXXXXXX         XXXXXXXXX         8632 Bright Route       Webster
# 3      XXXXXXXXX         XXXXXXXXX   2659 Jagged Rabbit View      Brooklyn
# 4      XXXXXXXXX         XXXXXXXXX          8434 Honey Pines        Ithaca
#
#   customer_state customer_zipcode
# 0             NY            11230
# ...
